# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import neural_nets

# %%
gen_model = neural_nets.All_Models(height=70, width=70, bins=1, years=10)
multi_input_cf_net_Ext_3class = gen_model.multi_input_cf_net_Ext()

# %% [markdown]
# ### Summary of the DNN Model

# %%
print ('number of params in cnn model: ', multi_input_cf_net_Ext_3class.count_params())

print ('summary of Model')
print ('\n')

multi_input_cf_net_Ext_3class.summary()
# Out:
# number of params in cnn model:  281187
# summary of Model
#
#
# Model: "2DCNN-CTAEXT"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 70, 70, 1)]  0           []
#
#  input_2 (InputLayer)           [(None, 70, 70, 1)]  0           []
#
#  input_3 (InputLayer)           [(None, 70, 70, 1)]  0           []
#
#  input_4 (InputLayer)           [(None, 70, 70, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 70, 70, 32)   320         ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 70, 70, 32)   320         ['input_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 70, 70, 32)   320         ['input_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 70, 70, 32)   320         ['input_4[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 35, 35, 32)   9248        ['conv2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 35, 35, 32)   9248        ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 35, 35, 32)   9248        ['conv2d_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 35, 35, 32)   9248        ['conv2d_6[0][0]']
#
#  concatenate (Concatenate)      (None, 35, 35, 128)  0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  batch_normalization (BatchNorm  (None, 35, 35, 128)  512        ['concatenate[0][0]']
#  alization)
#
#  conv2d_8 (Conv2D)              (None, 35, 35, 64)   73792       ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 17, 17, 64)   0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 17, 17, 64)   36928       ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)    0           ['conv2d_9[0][0]']
#
#  flatten (Flatten)              (None, 4096)         0           ['max_pooling2d_1[0][0]']
#
#  dense (Dense)                  (None, 32)           131104      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 16)           528         ['dense[0][0]']
#
#  dropout (Dropout)              (None, 16)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 3)            51          ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 281,187
# Trainable params: 280,931
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %% [markdown]
# ### Plot the DNN Model (Trainable = T)

# %%
from keras.utils.vis_utils import plot_model
plot_model(multi_input_cf_net_Ext_3class, rankdir='TB', show_shapes=True,)
